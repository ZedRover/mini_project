# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv",index_col=0)

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
from ydata_profiling import ProfileReport



profile = ProfileReport(df, title="Profiling Report")

# %%
profile.to_notebook_iframe()

# %%
profile.to_file("yadata_report.html")
